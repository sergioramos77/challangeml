# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
import sys
print(sys.version)
# Out:
# 1.23.4
# 1.5.1
# 0.12.2
# 3.10.6 (main, Oct  7 2022, 15:17:23) [Clang 12.0.0 ]

# %%
data = pd.read_csv('/Users/mertatalay/Desktop/programacionII/data/iris.data')

# %%
data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
data2 = pd.read_csv('/Users/mertatalay/Desktop/programacionII/data/iris.data', header=None)
data2.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
nom_iris = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

# %%
data2.columns = nom_iris

# %%
data2.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#base = datasets.load_iris()
base = sns.load_dataset('iris')
base.head()


#base = sns.load_dataset('iris')
#base.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
base.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(base.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(base.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(base, hue='species', height=5, aspect=2);

# %%
base.hist(edgecolor='red', linewidth=2, figsize=(16,10));
plt.show();

# %%
plt.figure(figsize=(12,8));
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=base)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=base)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=base)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=base);

# %%
base.boxplot(by='species', figsize=(14,6));

# %%
pd.plotting.scatter_matrix(base, figsize=(18,12))
plt.show()

# %%
sns.pairplot(base, hue="species", diag_kind="kde");
