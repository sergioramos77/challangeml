# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\ursuz\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.plot([1, -2, 3, 4, 1], [0.0, 0.1, 0.2, 0.7, 0.9])

# %%
def f(a):
    return np.exp(-x ** 3)

# %%
a = np.linspace(-2, 5, 200)

# %%
plt.plot(a, f(a), label="Función f(a)")
plt.xlabel("Eje $a$")
plt.ylabel("$f(a)$")
plt.legend()
plt.title("Función $f(a)$")
# Out:
# Text(0.5, 1.0, 'Función $f(a)$')

# %%
plt.plot(a, f(a), 'ro')
plt.plot(a, 1 - f(a), 'g--')

# %%
plt.plot(a, f(a), color='red', linestyle='', marker='o')
plt.plot(a, 1 - f(a), c='g', ls='--')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#plt.style.use("ggplot")  # Afecta a todos los plots

# %%
with plt.style.context('ggplot'):
    plt.plot(a, f(a))
    plt.plot(a, 1 - f(a))

# %%
with plt.xkcd():
    plt.plot(a, f(a))
    plt.plot(a, 1 - f(a))
    plt.xlabel("Eje a")

# %%
N = 1000
x = np.random.randn(N)
y = np.random.randn(N)

plt.scatter(x, y)

# %%
s = np.abs(10 + 10 * np.random.randn(N))
c = np.random.randn(N)

plt.scatter(x, y, s=s, c=c, cmap=plt.cm.Oranges)
plt.colorbar()

# %%
plt.scatter(x, y, s=s, c=c, cmap=plt.cm.Reds)
plt.colorbar()

# %%
def f(x, y):
    return x **3 - y **3

# %%
x = np.linspace(-10, 10)
y = np.linspace(-10, 10)
xx, yy = np.meshgrid(x, y)
zz = f(xx, yy)

plt.contour(xx, yy, zz)
plt.colorbar()

# %%
plt.contourf(xx, yy, zz, np.linspace(-10, 10, 1000))
plt.colorbar()

# %%
x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.subplot(211)
plt.plot(x, x**2)
plt.grid(False)
plt.title("Función cuadratica")

plt.subplot(212)
plt.plot(x, np.sin(x))
plt.grid(False)
plt.title("Función seno")
# Out:
# Text(0.5, 1.0, 'Función seno')

# %%
fig.tight_layout()
fig

# %%
def frecuencias(f1=10.0, f2=100.0):
    max_time = 0.5
    times = np.linspace(0, max_time, 1000)
    signal = np.sin(2 * np.pi * f1 * times) + np.cos(2 * np.pi * f2 * times)
    with plt.style.context("ggplot"):
        plt.plot(signal, label="Señal")
        plt.xlabel("Tiempo ($t$)")
        plt.title("Dos frecuencias")
        plt.legend()

frecuencias()

# %%
def g(x, y):
    return x**2 + np.sin(y) ** 2

# Necesitamos muchos puntos en la malla, para que cuando se
# crucen las líneas no se vean irregularidades
x = np.linspace(-4, 10, 1000)
y = np.linspace(-4, 10, 1000)

xx, yy = np.meshgrid(x, y)

zz = g(xx, yy)

# Podemos ajustar el tamaño de la figura con figsize
fig = plt.figure(figsize=(6, 6))

# Ajustamos para que tenga 13 niveles y que use el colormap Spectral
# Tenemos que asignar la salida a la variable cs para luego crear el colorbar
cs = plt.contourf(xx, yy, zz, np.linspace(-1, 2, 13), cmap=plt.cm.Spectral)

# Creamos la barra de colores
plt.colorbar()

# Con `colors='k'` dibujamos todas las líneas negras
# Asignamos la salida a la variable cs2 para crear las etiquetas
cs = plt.contour(xx, yy, zz, np.linspace(-1, 2, 13), colors='k')

# Creamos las etiquetas sobre las líneas
plt.clabel(cs)

# Ponemos las etiquetas de los ejes
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title(r"Función $g(x, y) = \ x^2 + \sin^2{y}$")
# Out:
# Text(0.5, 1.0, 'Función $g(x, y) = \\ x^2 + \\sin^2{y}$')
